# %% [markdown]
# # А/В-тест на данных Retail

# %% [markdown]
# 1. Импорт библиотек, загрузка и проверка данных

# %%
import pandas as pd

df = pd.read_csv('../data/online_retail_II.csv')

df.shape
# Out:
# (1067371, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.tail(15)
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067356  581587     22556   PLASTERS IN TIN CIRCUS PARADE         12
# 1067357  581587     22555        PLASTERS IN TIN STRONGMAN        12
# 1067358  581587     22728        ALARM CLOCK BAKELIKE PINK         4
# 1067359  581587     22727        ALARM CLOCK BAKELIKE RED          4
# 1067360  581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 1067361  581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 1067362  581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 1067363  581587     22629              SPACEBOY LUNCH BOX         12
# 1067364  581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 1067365  581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# ...

# %% [markdown]
# 2. Рассчитываем ARPPU

# %%
arppu = round(df['Price'].sum()/df['Customer ID'].nunique(), 2)
arppu
# Out:
# 835.18

# %% [markdown]
# 3. Создадим атрибут, хранящий месяц и год первого платежа клиента и создадим датафрейм с агрегатами

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['purchase_month'] = df['InvoiceDate'].dt.to_period('M')
grouped_df = df.groupby('purchase_month').agg(price_agg = ('Price','sum')
                                             ,customer_id_agg = ('Customer ID', 'nunique')).reset_index()
grouped_df.tail(15)
# Out:
#    purchase_month   price_agg  customer_id_agg
# 10        2010-10  265973.340             1577
# 11        2010-11  301913.862             1683
# 12        2010-12  426719.600              948
# 13        2011-01  172752.800              783
# 14        2011-02  127448.770              798
# 15        2011-03  171486.510             1020
# 16        2011-04  129164.961              899
# 17        2011-05  190685.460             1079
# 18        2011-06  200717.340             1051
# 19        2011-07  171906.791              993
# 20        2011-08  150385.680              980
# 21        2011-09  199235.212             1302
# 22        2011-10  263434.090             1425
# 23        2011-11  327149.850             1711
# 24        2011-12  133933.660              686

# %% [markdown]
# 4. Построим график, показывающий стоимость в зависимости от месяца

# %%
grouped_df.plot(kind = 'line', x = 'purchase_month', y = 'price_agg')
# Out:
# <Axes: xlabel='purchase_month'>

# %% [markdown]
# 5. Создадим атрибуты когорт и посмотрим в процентном соотношении сколько клиентов возвращаются через разное кол-во месяцев для разных когорт

# %%
df_cohort = df.groupby('Customer ID').agg(cohort_month = ('purchase_month', 'min'))
df = pd.merge(df, df_cohort, on = 'Customer ID', how = 'left')
df.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID Country purchase_month  \
# 1067366 2011-12-09 12:50:00   2.10      12680.0  France        2011-12
# 1067367 2011-12-09 12:50:00   4.15      12680.0  France        2011-12
# 1067368 2011-12-09 12:50:00   4.15      12680.0  France        2011-12
# 1067369 2011-12-09 12:50:00   4.95      12680.0  France        2011-12
# 1067370 2011-12-09 12:50:00  18.00      12680.0  France        2011-12
#
#         cohort_month
# 1067366      2011-08
# 1067367      2011-08
# 1067368      2011-08
# 1067369      2011-08
# ...

# %%
df['cohort_index'] = (df['purchase_month'].dt.year - df['cohort_month'].dt.year)*12 + (df['purchase_month'].dt.month - df['cohort_month'].dt.month)

# %%
df[['Customer ID', 'purchase_month', 'cohort_month', 'cohort_index']].tail(10)
# Out:
#          Customer ID purchase_month cohort_month  cohort_index
# 1067361      12680.0        2011-12      2011-08             4
# 1067362      12680.0        2011-12      2011-08             4
# 1067363      12680.0        2011-12      2011-08             4
# 1067364      12680.0        2011-12      2011-08             4
# 1067365      12680.0        2011-12      2011-08             4
# 1067366      12680.0        2011-12      2011-08             4
# 1067367      12680.0        2011-12      2011-08             4
# 1067368      12680.0        2011-12      2011-08             4
# 1067369      12680.0        2011-12      2011-08             4
# 1067370      12680.0        2011-12      2011-08             4

# %%
pivot = df.groupby(['cohort_month', 'cohort_index'])['Customer ID'].nunique().unstack()
retention = round(pivot.divide(pivot[0], axis=0) * 100,2)
print(retention.iloc[:10, :6])
# Out:
# cohort_index      0      1      2      3      4      5
# cohort_month
# 2009-12       100.0  37.51  34.26  42.78  39.23  39.04
# 2010-01       100.0  21.83  30.20  30.46  27.92  29.19
# 2010-02       100.0  30.03  22.59  30.30  25.62  20.94
# 2010-03       100.0  21.79  25.92  23.62  22.94  19.95
# 2010-04       100.0  23.02  19.93  16.15  18.56  23.02
# 2010-05       100.0  19.29  17.72  19.29  18.90  25.98
# 2010-06       100.0  21.56  19.70  20.45  23.05  28.25
# 2010-07       100.0  20.77  20.22  28.42  30.05  15.30
# 2010-08       100.0  24.68  31.65  32.28  18.35  13.29
# 2010-09       100.0  30.17  26.03  14.05   9.09  10.33

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(retention, annot=True, fmt='.0f', cmap='YlGnBu')
plt.title('Retention по когортам (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Проведём А/В тест. Проверим гипотезу, что разница суммы покупок в зависимости от страны (UK или Germany) статистически значима

# %%
df['Country'].value_counts()[:5]
# Out:
# Country
# United Kingdom    981330
# EIRE               17866
# Germany            17624
# France             14330
# Netherlands         5140
# Name: count, dtype: int64

# %%
group_uk = df[df['Country']=='United Kingdom']
group_ger = df[df['Country']=='Germany']

# %%
print('Для UK\nРазмер: ', group_uk.shape[0], 'строк\nСреднее: ', f"{group_uk['Price'].mean():,.2f}")
print('\nДля Германии\nРазмер: ', group_ger.shape[0], 'строк\nСреднее: ', f"{group_ger['Price'].mean():,.2f}")
# Out:
# Для UK
# Размер:  981330 строк
# Среднее:  4.54
#
# Для Германии
# Размер:  17624 строк
# Среднее:  3.83

# %%
from scipy import stats

t_stat, p_value = stats.ttest_ind(group_uk['Price'], group_ger['Price'])
print(f'p-value: {p_value:.2}')
# Out:
# p-value: 0.46

# %%
ci_uk = tuple(round(x, 2) for x in stats.t.interval(0.95, df=len(group_uk['Price'])-1, loc=group_uk['Price'].mean(), scale=stats.sem(group_uk['Price'])))
ci_ger = tuple(round(x, 2) for x in stats.t.interval(0.95, df=len(group_ger['Price'])-1, loc=group_ger['Price'].mean(), scale=stats.sem(group_ger['Price'])))

# %%
print(f"UK: среднее={group_uk['Price'].mean():.2f}, 95% ДИ={ci_uk}")
print(f"Germany:   среднее={group_ger['Price'].mean():.2f}, 95% ДИ={ci_ger}")
# Out:
# UK: среднее=4.54, 95% ДИ=(4.29, 4.79)
# Germany:   среднее=3.83, 95% ДИ=(3.6, 4.07)

# %% [markdown]
# Выводы по проделанной работе:
#
# 1. По когортному анализу видим сильную разницу возврата клиентов декабря 2009 года и последующих лет, что, вероятнее всего, связано с какими-то продуктовыми изменениями. Также видим хороший Retention по тепловой карте, что говорит нам о лояльности клиента.
# 2. Наблюдается фактор сезонности: пик выручки в декабре 2011 соответствует периоду перед выходными нового года. ARPPU = 835.18(£).
# 3. A/B тест показал статистически значимую разницу среднего чека между покупками в Соединенном Королевстве и Германии (p=0.46).
